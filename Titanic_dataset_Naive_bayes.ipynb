# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# %%
data = pd.read_csv("/content/titanic3.csv")

# %%
data
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %%
data.shape
# Out:
# (1310, 14)

# %%
data.corr()
# Out:
# <ipython-input-269-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
data.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
data['age'].replace(np.nan,data['age'].astype('float').mean(axis=0),inplace=True)
data['body'].replace(np.nan,data['body'].astype('float').mean(axis=0),inplace=True)
data['home.dest'].fillna('Unknown', inplace=True)
data['boat'].fillna('0', inplace=True)

# %%
data.head(4)
# Out:
#    pclass  survived                                  name     sex      age  \
# 0     1.0       1.0         Allen, Miss. Elisabeth Walton  female  29.0000
# 1     1.0       1.0        Allison, Master. Hudson Trevor    male   0.9167
# 2     1.0       0.0          Allison, Miss. Helen Loraine  female   2.0000
# 3     1.0       0.0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat        body  \
# 0    0.0    0.0   24160  211.3375       B5        S    2  160.809917
# 1    1.0    2.0  113781  151.5500  C22 C26        S   11  160.809917
# 2    1.0    2.0  113781  151.5500  C22 C26        S    0  160.809917
# 3    1.0    2.0  113781  151.5500  C22 C26        S    0  135.000000
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
data['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
data['sex'].nunique()
# Out:
# 2

# %%
data["sex"] = data["sex"].replace(to_replace=data["sex"].unique(),value=[1,0,2])

# %%
data= pd.get_dummies(data,drop_first=True)

# %%
y_train = data['survived']
x_train = data[['pclass', 'sex','age','sibsp','parch','fare']]

# %%
from sklearn.model_selection import train_test_split
train_data,test_data,train_target, test_target =train_test_split(x_train,y_train,train_size=0.8)  # 80% datas for training

# %%
from sklearn.model_selection import train_test_split

X = data.loc[:, ['pclass', 'age', 'sex']]
y = data.survived

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# Out:
# train size: (1048, 3)
# test size: (262, 3)

# %%
model = GaussianNB()
model.fit(X_train,y_train)
model.score(X_train,y_train)
# Out:
# 0.7700381679389313

# %%
X_test = X_test.dropna()
y_test = y_test.loc[X_test.index]
pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("accuracy score: ",accuracy_score(y_test,pred))
# Out:
# accuracy score:  0.7931034482758621
