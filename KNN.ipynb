# %% [markdown]
# Cross-validation - to increase the accuracy
# Hold-out cross-validation
# Leave-one out cross-validation
# K-Fold cross-validation
# GrisSearch-to identify the best fitting models(KNN / DT / anything) & to find the hyper parameter(Parameter passed while defining the model)
# Parameter- passed for training
#
# Optuna,Grid-search Library
